# %%
#Data source
#https://data.unicef.org/resources/data_explorer/unicef_f/?ag=UNICEF&df=GLOBAL_DATAFLOW&ver=1.0&dq=.MNCH_IPTP+MNCH_ITN+MNCH_ITN2+MNCH_ITNOWN+MNCH_ITNPREG+MNCH_MLRACT+MNCH_MLRCARE+MNCH_MLRDIAG..&startPeriod=2016&endPeriod=2020
#Also need PMI funding data

# %%
import pandas as pd

# %%
file="Data_Sources/fusion_GLOBAL_DATAFLOW_UNICEF_1.0_all.csv"

# %%
df=pd.read_csv(file)
# Out:
# C:\Users\clemi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3,16,17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head(5)
# Out:
#   Geographic area              Indicator     Sex TIME_PERIOD  \
# 0     Afghanistan  Infant mortality rate  Female        1962
# 1     Afghanistan  Infant mortality rate  Female        1963
# 2     Afghanistan  Infant mortality rate  Female        1964
# 3     Afghanistan  Infant mortality rate  Female        1965
# 4     Afghanistan  Infant mortality rate  Female        1966
#
#           OBS_VALUE Unit multiplier              Unit of measure  \
# 0  219.791533838726             NaN  Deaths per 1000 live births
# 1  215.935231153578             NaN  Deaths per 1000 live births
# 2  212.297056547714             NaN  Deaths per 1000 live births
# 3  208.879545950226             NaN  Deaths per 1000 live births
# 4  205.311653691247             NaN  Deaths per 1000 live births
#
#   Observation Status Observation confidentaility       LOWER_BOUND  ...  \
# 0       Normal value                         NaN  188.768936057188  ...
# ...

# %%
#df["Geographic area"].unique()

# %%
african_countries={"Algeria","Angola","Benin","Botswana","Burkina Faso","Burundi","Cameroon","Central African Republic",
                   "Chad","Democratic Republic of the Congo","Republic of the Congo","Ivory Coast","Djibouti","Egypt",
                   "Equatorial Guinea","Eritrea","Swaziland","Ethiopia","Gabon","Gambia","Ghana","Guinea","Guinea Bissau",
                   "Kenya","Lesotho","Liberia","Libya","Madagascar","Malawi","Mali", "Mauritania","Morocco","Mozambique",
                   "Namibia","Niger","Nigeria","Rwanda","Senegal","Sierra Leone","Somalia","South Africa",
                    "South Sudan","Sudan","Tanzania","Togo","Tunisia","Uganda","Zambia","Zimbabwe"}

# %%
africa_list=pd.DataFrame(african_countries)

# %%
africa_list.head(5)
# Out:
#                        0
# 0                 Malawi
# 1               Tanzania
# 2           South Africa
# 3                 Guinea
# 4  Republic of the Congo

# %%
africa_list["continent"]="Africa"

# %%
africa_list.head(5)
# Out:
#                        0 continent
# 0                 Malawi    Africa
# 1               Tanzania    Africa
# 2           South Africa    Africa
# 3                 Guinea    Africa
# 4  Republic of the Congo    Africa

# %%
country_list=africa_list.rename(columns={0:"Geographic area"})

# %%
country_list.head(5)
# Out:
#          Geographic area continent
# 0                 Malawi    Africa
# 1               Tanzania    Africa
# 2           South Africa    Africa
# 3                 Guinea    Africa
# 4  Republic of the Congo    Africa

# %%
merged_df=pd.merge(df,country_list,how="inner",on="Geographic area")

# %%
merged_df.head(5)
# Out:
#   Geographic area              Indicator     Sex TIME_PERIOD  \
# 0         Algeria  Infant mortality rate  Female        1954
# 1         Algeria  Infant mortality rate  Female        1955
# 2         Algeria  Infant mortality rate  Female        1956
# 3         Algeria  Infant mortality rate  Female        1957
# 4         Algeria  Infant mortality rate  Female        1958
#
#           OBS_VALUE Unit multiplier              Unit of measure  \
# 0  140.478076964498             NaN  Deaths per 1000 live births
# 1  140.204233486295             NaN  Deaths per 1000 live births
# 2  140.120652645222             NaN  Deaths per 1000 live births
# 3  139.949659665834             NaN  Deaths per 1000 live births
# 4  139.776068575784             NaN  Deaths per 1000 live births
#
#   Observation Status Observation confidentaility       LOWER_BOUND  ...  \
# 0       Normal value                         NaN  111.977302130197  ...
# ...

# %%
merged_df.dtypes
# Out:
# Geographic area                                                 object
# Indicator                                                       object
# Sex                                                             object
# TIME_PERIOD                                                     object
# OBS_VALUE                                                       object
# Unit multiplier                                                 object
# Unit of measure                                                 object
# Observation Status                                              object
# Observation confidentaility                                     object
# LOWER_BOUND                                                     object
# UPPER_BOUND                                                     object
# WGTD_SAMPL_SIZE                                                float64
# OBS_FOOTNOTE                                                    object
# ...

# %%
merged_df['TIME_PERIOD'].unique()
# Out:
# array([1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#        1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#        1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957',
#        '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
# ...

# %%
merged_df.to_csv('../US_Africa_Policy/Resources/unicef_africa_data.csv',index=False)
